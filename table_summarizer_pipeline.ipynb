# %% [markdown]
# # Table Detection, Extraction and Summarization Pipeline
#
# This notebook:
# 1. Detects if an image contains a table using TATR detection model.
# 2. If a table is present, extracts and OCRs its cells then summarizes.
# 3. If no table, performs full-image OCR.

# %%
# Install required packages
# !pip install transformers torch paddleocr opencv-python numpy pandas
# Out:
# Requirement already satisfied: transformers in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (4.36.2)
# Requirement already satisfied: torch in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (2.7.0)
# Requirement already satisfied: paddleocr in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (2.10.0)
# Requirement already satisfied: opencv-python in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (1.24.3)
# Requirement already satisfied: pandas in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (2.2.3)
# Requirement already satisfied: filelock in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from transformers) (0.30.2)
# Requirement already satisfied: packaging>=20.0 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from torch) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: shapely in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (2.1.0)
# Requirement already satisfied: scikit-image in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (0.25.2)
# Requirement already satisfied: pyclipper in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (1.3.0.post6)
# Requirement already satisfied: lmdb in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (1.6.2)
# Requirement already satisfied: rapidfuzz in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (3.13.0)
# Requirement already satisfied: opencv-contrib-python in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (4.11.0.86)
# Requirement already satisfied: cython in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (3.0.12)
# Requirement already satisfied: Pillow in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (11.2.1)
# Requirement already satisfied: python-docx in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (1.1.2)
# Requirement already satisfied: beautifulsoup4 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (4.13.4)
# Requirement already satisfied: fonttools>=4.24.0 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (4.57.0)
# Requirement already satisfied: fire>=0.3.0 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (0.7.0)
# Requirement already satisfied: albumentations in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (1.3.1)
# Requirement already satisfied: albucore in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from paddleocr) (0.0.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: termcolor in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from fire>=0.3.0->paddleocr) (3.1.0)
# Requirement already satisfied: six>=1.5 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from albucore->paddleocr) (4.11.0.86)
# Requirement already satisfied: scipy>=1.1.0 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from albumentations->paddleocr) (1.15.2)
# Requirement already satisfied: qudida>=0.0.4 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from albumentations->paddleocr) (0.0.4)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from scikit-image->paddleocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from scikit-image->paddleocr) (2025.3.30)
# Requirement already satisfied: lazy-loader>=0.4 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from scikit-image->paddleocr) (0.4)
# Requirement already satisfied: soupsieve>1.2 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from beautifulsoup4->paddleocr) (2.7)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: lxml>=3.1.0 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from python-docx->paddleocr) (5.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: scikit-learn>=0.19.1 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from qudida>=0.0.4->albumentations->paddleocr) (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations->paddleocr) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\jobs\jusbundle\experiment\summarizor\venv_new\lib\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations->paddleocr) (3.6.0)
# [notice] A new release of pip available: 22.3 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import json
import cv2
import torch
import numpy as np
import pandas as pd
from datetime import datetime
from transformers import (
    TableTransformerForObjectDetection,
    DetrImageProcessor,
    T5ForConditionalGeneration,
    AutoTokenizer
)
from paddleocr import PaddleOCR

# %% [markdown]
# ## 1. Table Detection Function

# %%
def is_table_image(image_path, detect_thresh=0.5):
    '''Detect if the image contains a table region using TATR detection model'''
    MODEL_DET = "microsoft/table-transformer-structure-recognition-v1.1-all"
    proc_det = DetrImageProcessor.from_pretrained(MODEL_DET)
    model_det = TableTransformerForObjectDetection.from_pretrained(MODEL_DET).eval()
    # 2) read & preprocess
    img_bgr = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

    # 3) run it through TATR
    inputs = proc_det(images=img_rgb, return_tensors="pt", size={"height": img_rgb.shape[0], "width": img_rgb.shape[1]})
    outputs = model_det(**inputs)

    # 4) post‐process detections
    target_sizes = torch.tensor([img_rgb.shape[:2]])
    results = proc_det.post_process_object_detection(
        outputs, threshold=detect_thresh, target_sizes=target_sizes
    )[0]
    
        # 5) check for any 'table row' / 'table column' labels
    id2label = model_det.config.id2label
    highest_confidence = 0.0
    is_table = False
    
    for score, lbl in zip(results["scores"], results["labels"]):
        if score < detect_thresh:
            continue
        name = id2label[int(lbl.item())]
        if name in ("table row", "table column"):
            confidence = float(score.item())
            highest_confidence = max(highest_confidence, confidence)
            is_table = True

    return is_table, highest_confidence

# %% [markdown]
# ## 2. Table Extraction Function

# %%
def extract_table_from_image(image_path, detect_thresh=0.9):
    '''Extract table structure and content from an image using TATR structure-recognition'''
    MODEL_NAME = 'microsoft/table-transformer-structure-recognition-v1.1-all'
    processor = DetrImageProcessor.from_pretrained(MODEL_NAME)
    model = TableTransformerForObjectDetection.from_pretrained(MODEL_NAME)
    model.eval()
    ocr = PaddleOCR(use_angle_cls=True, lang='en')
    img_bgr = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    inputs  = processor(images=img_rgb, return_tensors="pt", size={"height": img_rgb.shape[0], "width": img_rgb.shape[1]})
    outputs = model(**inputs)
    target_sizes = torch.tensor([img_rgb.shape[:2]])
    results = processor.post_process_object_detection(
        outputs, threshold=detect_thresh, target_sizes=target_sizes
    )[0]
    rows, columns = [], []
    for score, label, box in zip(results['scores'], results['labels'], results['boxes']):
        if score < detect_thresh: continue
        xmin, ymin, xmax, ymax = map(int, box.tolist())
        obj = model.config.id2label[int(label.item())]
        if obj == 'table row': rows.append((ymin, ymax))
        elif obj == 'table column': columns.append((xmin, xmax))
    rows = sorted(rows, key=lambda r: r[0])
    columns = sorted(columns, key=lambda c: c[0])
    cell_bboxes=[]
    for i, (y0,y1) in enumerate(rows):
        for j,(x0,x1) in enumerate(columns):
            cell_bboxes.append({'row':i,'col':j,'bbox':{'xmin':x0,'ymin':y0,'xmax':x1,'ymax':y1}})
    data = [['' for _ in columns] for _ in rows]
    for c in cell_bboxes:
        r,cidx=c['row'],c['col']
        b=c['bbox']
        crop=img_bgr[b['ymin']:b['ymax'],b['xmin']:b['xmax']]
        res = ocr.ocr(crop, cls=True)
        text = ""
        if res:
            text_lines = []
            for block in res:
                if block:
                    text_lines.extend([line[1][0] for line in block if line])
            text = " ".join(text_lines).strip()
        data[r][cidx] = text

    return data

# %% [markdown]
# ## 3. Full Image OCR Function

# %%
def ocr_full_image(image_path):
    '''Extract all text from an image using PaddleOCR'''
    ocr = PaddleOCR(use_angle_cls=True, lang='en')
    img = cv2.imread(image_path)
    res = ocr.ocr(img, cls=True)
    if res is None:
        return ''
    lines = [ln[1][0] for blk in res for ln in blk]
    return ''.join(lines)

# %% [markdown]
# ## 4. Table Text Formatting & Summarization

# %%
def format_table_as_text(data):
    header=[h.strip() for h in data[0]]
    rows=data[1:]
    lines=["Table Contents:"]
    for row in rows:
        if not any(cell.strip() for cell in row): continue
        label=row[0].strip()
        parts=[]
        for i,val in enumerate(row[1:],start=1):
            if (v:=val.strip()): parts.append(f"{header[i]} {v}")
        lines.append(f"- {label}: "+'; '.join(parts) if parts else f"- {label}")
    return ''.join(lines)

def format_table_for_flant5(data):
    body=format_table_as_text(data)
    return 'Summarize the following table: '+body

# %% [markdown]
# ## 5. Summarization Function

# %%
def summarize_text(text, model_name="google/flan-t5-xl", max_length=256, min_length=64):
    tokenizer=AutoTokenizer.from_pretrained(model_name)
    model=T5ForConditionalGeneration.from_pretrained(model_name).to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
    inputs=tokenizer(text,return_tensors="pt",truncation=True,max_length=4096).to(model.device)
    ids = model.generate(inputs.input_ids, attention_mask=inputs.attention_mask, max_length=max_length, min_length=min_length, num_beams=4, length_penalty=2.0, early_stopping=True)
    return tokenizer.decode(ids[0],skip_special_tokens=True)

# %% [markdown]
# ## 6. Combined Pipeline Function

# %%
def process_table_image(image_path, model_name="google/flan-t5-xl"):
    is_table, confidence = is_table_image(image_path)
    if is_table:
        data=extract_table_from_image(image_path)
        if data and len(data) > 0:
            table_text = format_table_for_flant5(data)
            summary = summarize_text(table_text, model_name)
            return {
                'type': 'table',
                'table_data': data,
                'table_text': table_text,
                'summary': summary
            }
        else:
            # If no table data was extracted despite detection, fall back to OCR
            txt = ocr_full_image(image_path)
            return {
                'type': 'text',
                'ocr_text': txt
            }
    else:
        txt=ocr_full_image(image_path)
        return {
            'type':'text',
            'ocr_text':txt
        }

# %% [markdown]
# ## 7. Save Results Function

# %%
def save_results_to_json(result, output_file="table_summary_result.json"):
    res_copy=result.copy()
    res_copy['timestamp']=datetime.now().isoformat()
    with open(output_file,'w',encoding='utf-8') as f: json.dump(res_copy,f,indent=2,ensure_ascii=False)
    return output_file

# %% [markdown]
# ## 8. Example Usage

# %%
# Test with a table image:
res=process_table_image("client_table_1.png")
print(res)
# Test with a non-table image:
res2=process_table_image("figure_example.png")
print(res2)
# Save:
print(save_results_to_json(res))
# Out:
# [2025/05/08 03:26:25] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\looya/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\looya/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='d:\\JOBS\\JUSBUNDLE\\Experiment\\summarizor\\venv_new\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\looya/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/05/08 03:26:27] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.12102508544921875
# [2025/05/08 03:26:27] ppocr DEBUG: cls num  : 1, elapsed : 0.0820000171661377
# [2025/05/08 03:26:27] ppocr DEBUG: rec_res num  : 1, elapsed : 0.15404891967773438
# [2025/05/08 03:26:27] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.10051274299621582
# [2025/05/08 03:26:27] ppocr DEBUG: cls num  : 1, elapsed : 0.011002063751220703
# [2025/05/08 03:26:27] ppocr DEBUG: rec_res num  : 1, elapsed : 0.054941415786743164
# [2025/05/08 03:26:27] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.013558149337768555
# [2025/05/08 03:26:27] ppocr DEBUG: cls num  : 1, elapsed : 0.00799870491027832
# [2025/05/08 03:26:27] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04874062538146973
# [2025/05/08 03:26:27] ppocr DEBUG: dt_boxes num : 3, elapsed : 0.016509294509887695
# [2025/05/08 03:26:27] ppocr DEBUG: cls num  : 3, elapsed : 0.07955765724182129
# [2025/05/08 03:26:27] ppocr DEBUG: rec_res num  : 3, elapsed : 0.18903565406799316
# [2025/05/08 03:26:27] ppocr DEBUG: dt_boxes num : 2, elapsed : 0.01200413703918457
# [2025/05/08 03:26:28] ppocr DEBUG: cls num  : 2, elapsed : 0.07350945472717285
# [2025/05/08 03:26:28] ppocr DEBUG: rec_res num  : 2, elapsed : 0.16969037055969238
# [2025/05/08 03:26:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.0939021110534668
# [2025/05/08 03:26:28] ppocr DEBUG: cls num  : 1, elapsed : 0.008001327514648438
# [2025/05/08 03:26:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04699873924255371
# [2025/05/08 03:26:28] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.07350778579711914
# [2025/05/08 03:26:28] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:28] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:28] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.009995222091674805
# [2025/05/08 03:26:28] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:28] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:28] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.011002540588378906
# [2025/05/08 03:26:28] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:28] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:28] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.011000633239746094
# [2025/05/08 03:26:28] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:28] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01100015640258789
# [2025/05/08 03:26:28] ppocr DEBUG: cls num  : 1, elapsed : 0.011001348495483398
# [2025/05/08 03:26:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.1425168514251709
# [2025/05/08 03:26:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01100015640258789
# [2025/05/08 03:26:28] ppocr DEBUG: cls num  : 1, elapsed : 0.008006095886230469
# [2025/05/08 03:26:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.046508073806762695
# [2025/05/08 03:26:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.011000394821166992
# [2025/05/08 03:26:28] ppocr DEBUG: cls num  : 1, elapsed : 0.009000062942504883
# [2025/05/08 03:26:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04651212692260742
# [2025/05/08 03:26:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.011000633239746094
# [2025/05/08 03:26:28] ppocr DEBUG: cls num  : 1, elapsed : 0.009997129440307617
# [2025/05/08 03:26:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04800152778625488
# [2025/05/08 03:26:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.011003255844116211
# [2025/05/08 03:26:28] ppocr DEBUG: cls num  : 1, elapsed : 0.007506608963012695
# [2025/05/08 03:26:28] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04600024223327637
# [2025/05/08 03:26:28] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.011999845504760742
# [2025/05/08 03:26:28] ppocr DEBUG: cls num  : 1, elapsed : 0.008000612258911133
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.052509307861328125
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.009999752044677734
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 1, elapsed : 0.006998538970947266
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.0500030517578125
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010506391525268555
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 1, elapsed : 0.007999897003173828
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04900050163269043
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.011999368667602539
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 1, elapsed : 0.00801396369934082
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05050849914550781
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.010000228881835938
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.012004375457763672
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 1, elapsed : 0.009001016616821289
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.048514604568481445
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010839223861694336
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 1, elapsed : 0.009017229080200195
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.049004316329956055
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.011508941650390625
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 1, elapsed : 0.008002042770385742
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05100059509277344
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.012000560760498047
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 1, elapsed : 0.009004831314086914
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04951333999633789
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.010999441146850586
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.009998559951782227
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 1, elapsed : 0.0070002079010009766
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.13503098487854004
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.013000965118408203
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 1, elapsed : 0.00899958610534668
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.10685944557189941
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.009999990463256836
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.012504339218139648
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 1, elapsed : 0.009000301361083984
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05137753486633301
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.011561155319213867
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:29] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:29] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01324462890625
# [2025/05/08 03:26:29] ppocr DEBUG: cls num  : 1, elapsed : 0.008005380630493164
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.048711538314819336
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.011997699737548828
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.013002157211303711
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 1, elapsed : 0.007999420166015625
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04703569412231445
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010999917984008789
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 1, elapsed : 0.007999897003173828
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.0429990291595459
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010999917984008789
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 1, elapsed : 0.008002996444702148
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.047515153884887695
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010998964309692383
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 1, elapsed : 0.007361650466918945
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04851174354553223
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.008000850677490234
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.009999990463256836
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.010998964309692383
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.012000799179077148
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01300048828125
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 1, elapsed : 0.00899958610534668
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04951643943786621
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.013000249862670898
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 1, elapsed : 0.008002281188964844
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.049526214599609375
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.011999368667602539
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 1, elapsed : 0.008000612258911133
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04700016975402832
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.012002944946289062
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 1, elapsed : 0.008508682250976562
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04800009727478027
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.011000633239746094
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 1, elapsed : 0.007998228073120117
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.040513038635253906
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010999679565429688
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 1, elapsed : 0.008999824523925781
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04399991035461426
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.011004209518432617
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 1, elapsed : 0.00850820541381836
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04799842834472656
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.010999917984008789
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.00899958610534668
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 1, elapsed : 0.006999969482421875
# [2025/05/08 03:26:30] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04885435104370117
# [2025/05/08 03:26:30] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010999917984008789
# [2025/05/08 03:26:30] ppocr DEBUG: cls num  : 1, elapsed : 0.007999181747436523
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04551410675048828
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.012000322341918945
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 1, elapsed : 0.008001089096069336
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04700064659118652
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.008999109268188477
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.010008096694946289
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.01203155517578125
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.01399850845336914
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010999202728271484
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 1, elapsed : 0.018524885177612305
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05052495002746582
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.013000726699829102
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.011996984481811523
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.013000011444091797
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 1, elapsed : 0.00799870491027832
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 1, elapsed : 0.049175262451171875
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.015000343322753906
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 1, elapsed : 0.01200103759765625
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 1, elapsed : 0.05200338363647461
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.014502525329589844
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 1, elapsed : 0.007997751235961914
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04800128936767578
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.0110015869140625
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.012998580932617188
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.010998249053955078
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 1, elapsed : 0.007999181747436523
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04300093650817871
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01300048828125
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 1, elapsed : 0.008005857467651367
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 1, elapsed : 0.04717540740966797
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 1, elapsed : 0.01199960708618164
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 1, elapsed : 0.009000062942504883
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 1, elapsed : 0.050514936447143555
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.011000394821166992
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.012998819351196289
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.009999513626098633
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# [2025/05/08 03:26:31] ppocr DEBUG: dt_boxes num : 0, elapsed : 0.00999903678894043
# [2025/05/08 03:26:31] ppocr DEBUG: cls num  : 0, elapsed : 0
# [2025/05/08 03:26:31] ppocr DEBUG: rec_res num  : 0, elapsed : 0.0
# Loading checkpoint shards: 100%|██████████| 2/2 [00:20<00:00, 10.16s/it]
# {'type': 'table', 'table_data': [["(Amt in $'000)", 'Notes', 'Book value', 'Estimated ealisable value ("ERV")', 'Liquidation Scenario'], ['ASSETS', '', '', '', ''], ['Sundry debtors', 'a', '9,760', '5,548', '666'], ['Cash in bank', 'b', '0', '0', ''], ['Other assets', 'C', '1,438', '107', ''], ['Contingent assets', 'p', '', '28', ''], ['Total assets', '', '11,198', '5,683', '666'], ['LIABILITIES', '', '', '', ''], ['Total creditors', '-', '(335)', '(7,312)', '(9,940'], ['Contingent', 'f', '', '(9,707)', '(9,633'], ['liabilities', '', '', '', ''], ['Total liabilities', '', '', '(17,019)', '(19,573)'], ['Estimated', '', '', '(11,336)3', '(18,907)'], ['deficiency', '', '', '', '']], 'table_text': 'Summarize the following table: Table Contents:- ASSETS- Sundry debtors: Notes a; Book value 9,760; Estimated ealisable value ("ERV") 5,548; Liquidation Scenario 666- Cash in bank: Notes b; Book value 0; Estimated ealisable value ("ERV") 0- Other assets: Notes C; Book value 1,438; Estimated ealisable value ("ERV") 107- Contingent assets: Notes p; Estimated ealisable value ("ERV") 28- Total assets: Book value 11,198; Estimated ealisable value ("ERV") 5,683; Liquidation Scenario 666- LIABILITIES- Total creditors: Notes -; Book value (335); Estimated ealisable value ("ERV") (7,312); Liquidation Scenario (9,940- Contingent: Notes f; Estimated ealisable value ("ERV") (9,707); Liquidation Scenario (9,633- liabilities- Total liabilities: Estimated ealisable value ("ERV") (17,019); Liquidation Scenario (19,573)- Estimated: Estimated ealisable value ("ERV") (11,336)3; Liquidation Scenario (18,907)- deficiency', 'summary': 'Liquidation Scenario 666- Total assets: Book value 11,198; Estimated ealisable value ("ERV") 5,683; Liquidation Scenario 666- Liabilities: Total creditors: Notes -; Book value (335); Estimated ealisable value ("ERV") (7,312); Liquidation Scenario (9,940- Contingent: Notes f; Estimated ealisable value ("ERV") (9,707); Liquidation Scenario (9,633- deficiency: Estimated ealisable value ("ERV") (11,336)3; Liquidation Scenario (18,907)- deficiency'}
# [2025/05/08 03:28:54] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\looya/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\looya/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='d:\\JOBS\\JUSBUNDLE\\Experiment\\summarizor\\venv_new\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\looya/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/05/08 03:28:55] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\looya/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\looya/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='d:\\JOBS\\JUSBUNDLE\\Experiment\\summarizor\\venv_new\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\looya/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# [2025/05/08 03:28:57] ppocr DEBUG: dt_boxes num : 26, elapsed : 0.4769022464752197
# [2025/05/08 03:28:57] ppocr DEBUG: cls num  : 26, elapsed : 0.21953630447387695
# [2025/05/08 03:28:59] ppocr DEBUG: rec_res num  : 26, elapsed : 2.061746120452881
# {'type': 'text', 'ocr_text': '3MENTIUNI/REMARKS/NOTESREPUBLICA MOLDOVA-REPUBLIC OF MOLDOVA-REPUBLIQUE DE MOLDOVAPASAPORTPASSPORTPASSEPORTTipul/Type/TypeMDAAB1555604MDAPASMIRNOVIGORREPUBLICA MOLDOVAmarud dei150619952004042042053REPUBLICA MOLDOVADate of issue/Dstaexpirari/Date efexpirye1310202113 102031AGENTIA SERVICII PUBLICEPAMDASMIRNOVIGOR<<AB15556045MDA9506158M31101312004042042053<48'}
# table_summary_result.json
